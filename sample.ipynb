# %%
# !pip install git+https://github.com/butchi/colab-gpt-kernel.git

# %%
# %load_ext gpt_magic
# Out:
# GPTマジック（%%gpt）を登録しました。セルの先頭に %%gpt 、続いてメッセージを入れてShift + Enterを押してください。また、最初にAPIキーをシークレットの openaiApiKey にセットしてください。

# %%
# %%gpt
# 以下の文章をMarkdown形式で要約してください。
# 人工知能（AI）は、コンピュータが人間のように学習、推論、問題解決を行う能力を指します。近年、AI技術は急速に進化しており、自然言語処理、画像認識、音声認識など、多くの分野で応用されています。特に、ディープラーニングと呼ばれる手法が注目されており、大量のデータを用いてモデルを訓練することで、高精度な予測や分類が可能となっています。AIは医療、金融、製造業など様々な産業で活用されており、効率化や新たな価値創造に寄与しています。しかし、一方で倫理的な課題やプライバシーの問題も存在し、これらに対する適切な対応が求められています。
# Out:
# [INFO] Using model: gpt-5 (default)
# ## 要約
#
# - 人工知能（AI）は、コンピュータが学習・推論・問題解決を行う能力を指す。
# - 近年、AIは急速に進化し、自然言語処理・画像認識・音声認識などで広く応用。
# - ディープラーニングにより、大量データを用いた高精度な予測・分類が可能に。
# - 医療・金融・製造業などで効率化や新たな価値創造に貢献。
# - 一方で、倫理的課題やプライバシー問題が存在し、適切な対応が求められる。
